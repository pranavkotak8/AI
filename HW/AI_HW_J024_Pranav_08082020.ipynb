# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavkotak8/AI/blob/master/HW/AI_HW_J024_Pranav_08082020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Knapsack Problem:**

# %%
"""
Example Input for the Problem for explanation:

INPUT:

1
5 3
1 1 1 1 1
3 5 2 2 3
1 2
1 3
2 4
2 5

OUTPUT:

11



DRY RUN for the Knapsack Problem:

1. Taking the Inputs as following:
  i) Number of test cases in the first line:
     1

  ii) The number of nodes(n) and the knapsack size(m):
    5 3

  iii) The Size of the item associated with the node n. Here there are 5 nodes so there will be 5 sizes respectively.
    1 1 1 1 1

  iv) The value of each item respectively.
    3 5 2 2 3
  
   v) The subset pairs which are connected.
   1 2
   1 3
   2 4
   2 5

2. To find the maximum value of items:

Value  |  Size         The matrix for computation of the largest value:
------ |-------        
  3    |   1         i/s| 0 | 1 | 2 | 3 | 4 |
  5    |   1        ----------------------------------------------- 
  2    |   1          0 | 0   0   0   0   0   |    
  2    |   1          1 | 0   3   3   3   3   |
  3    |   1          2 | 0   5   8   8   8   |
                      3 | 0   5   7   9   10  |
                      4 | 0   5   7   9   10  |
                      5 | 0   5   8   10  *11*|
                    ---------------------------------------------------
                    For the computation of the second iteration:
                    i=2
                    when we have s=1, we have two options (1,3) and (1,5).
                    so we will select max(5+0,3)=max(5,3)=5
                    Same way for the other values of s:
                    s=2,i=2 => max(5+0,3)=max(5,3)=5
                    s=3,i=2 => max(5+3,3)=max(8,3)=8
                    s=4,i=2 => max(5+3,3)=max(8,3)=8
                    Doing it for all the values of i, we select the last value of the matrix
                    here in the above example it is showed as *11*.

                    We will see the same output through the python code as well below.

[The size should be in increasing order. Here its already there so no change.]

"""


# Code:

def knapsack(N,M,S,V,E) :

    T = tuple(set() for _ in range(N))
    for u,v in E :
        T[u].add(v)
        T[v].add(u)
    Total, order, maxValue = sum(V), sorted(range(n), reverse=True, key=(lambda i : V[i]/S[i])), 0

    #to fetch the maximum value of all the values:

    def getMax(visited, connected, rejected, size, value, rejectedValue, maxValue) :
        if value > maxValue :
            maxValue = value
            
        if not connected :
            return maxValue
        
        i = getBest(connected)

        if size + S[i] <= M :
            maxValue = getMax(visited|{i}, (connected-{i}) | (T[i]-rejected-visited), rejected, size+S[i], value+V[i], rejectedValue, maxValue)
            
        if Total - (rejectedValue + V[i]) > maxValue :
            maxValue = getMax(visited|{i}, connected-{i}, rejected | {i}, size, value, rejectedValue + V[i], maxValue)
            
        return maxValue

    def getBest(connected) :
        for i in order :
            if i in connected :
                return i
            
    for s in order :
        maxValue = getMax(set(),{s},set(),0,0,0,maxValue)

    return maxValue

# taking the required inputs from the user:
T = int(input())
for _ in range(T) :
    n,m = (int(_) for _ in input().split())
    s = tuple(int(_) for _ in input().split())
    v = tuple(int(_) for _ in input().split())
    e = tuple((int(_)-1 for _ in input().split()) for _ in range(n-1))
    print(knapsack(n,m,s,v,e))
# Out:
# 1
# 5 3
# 1 1 1 1 1
# 3 5 2 2 3
# 1 2
# 1 3
# 2 4
# 2 5
# 11
